# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### *Learning rate = 2.e-5*

# %%
filename = 'G:\\ltyworkstuff\\postdoc\\Results\\TRGAN_Michele_NEI\\output\\TRGAN_Michele_NEI64_KW1_SW1_NGO32_LR0.00002_AR1.e-1_VG0_OL0\\KLD.csv'
df_KLD = pd.read_csv(filename)

# %%
plt.figure(figsize=(6, 4), dpi=100)
plt.yscale("log")
plt.xlabel('epoch', fontsize=11)
plt.ylabel('$\mathcal{D}[P(u^\prime)||Q_{\mathrm{e}}(u^\prime)]$', fontsize=12)

plt.plot(df_KLD.index+1, df_KLD['KLD_train'], label='training data')
plt.plot(df_KLD.index+1, df_KLD['KLD_dev'], label='validation data')

# The line $\mathcal{D}[P(u^\prime)||Q_{\mathrm{e}}(u^\prime)]=0.005$
plt.plot([1,500], [5.e-3,5.e-3], '--k', label='$\mathcal{D}[P(u^\prime)||Q_{\mathrm{e}}(u^\prime)]=0.005$')

plt.legend()

ymin, ymax = plt.gca().get_ylim()

plt.plot([350, 350], [ymin, ymax], '--k', lw=1)

plt.ylim(ymin, ymax)

plt.annotate('(a) lr=2.e-5', (0.1, 0.9), xycoords='axes fraction', fontsize=12)
# Out:
# Text(0.1, 0.9, '(a) lr=2.e-5')

# %% [markdown]
# ### *Learning rate = 1.e-5*

# %%
filename = 'G:\\ltyworkstuff\\postdoc\\Results\\TRGAN_Michele_NEI\\output\\TRGAN_Michele_NEI64_KW1_SW1_NGO32_LR0.00001_AR1.e-1_VG0_OL0\\KLD.csv'
df_KLD = pd.read_csv(filename)

# %%
plt.figure(figsize=(6, 4), dpi=100)
plt.yscale("log")
plt.xlabel('epoch', fontsize=11)
plt.ylabel('$\mathcal{D}[P(u^\prime)||Q_{\mathrm{e}}(u^\prime)]$', fontsize=12)

plt.plot(df_KLD.index+1, df_KLD['KLD_train'], label='training data')
plt.plot(df_KLD.index+1, df_KLD['KLD_dev'], label='validation data')

# The line $\mathcal{D}[P(u^\prime)||Q_{\mathrm{e}}(u^\prime)]=0.005$
plt.plot([1,500], [5.e-3,5.e-3], '--k', label='$\mathcal{D}[P(u^\prime)||Q_{\mathrm{e}}(u^\prime)]=0.005$')

ymin, ymax = plt.gca().get_ylim()

plt.plot([50, 50], [ymin, ymax], '--k', lw=1)

plt.ylim(ymin, ymax)

plt.annotate('(b) lr=1.e-5', (0.1, 0.9), xycoords='axes fraction', fontsize=12)
# Out:
# Text(0.1, 0.9, '(b) lr=1.e-5')

# %% [markdown]
# ### *Learning rate = 2.e-6*

# %%
filename = 'G:\\ltyworkstuff\\postdoc\\Results\\TRGAN_Michele_NEI\\output\\TRGAN_Michele_NEI64_KW1_SW1_NGO32_LR0.000002_AR1.e-1_VG0_OL0\\KLD.csv'
df_KLD = pd.read_csv(filename)

# %%
plt.figure(figsize=(6, 4), dpi=100)
plt.yscale("log")
plt.xlabel('epoch', fontsize=11)
plt.ylabel('$\mathcal{D}[P(u^\prime)||Q_{\mathrm{e}}(u^\prime)]$', fontsize=12)

plt.plot(df_KLD.index+1, df_KLD['KLD_train'], label='training data')
plt.plot(df_KLD.index+1, df_KLD['KLD_dev'], label='validation data')

# The line $\mathcal{D}[P(u^\prime)||Q_{\mathrm{e}}(u^\prime)]=0.005$
plt.plot([1,500], [5.e-3,5.e-3], '--k', label='$\mathcal{D}[P(u^\prime)||Q_{\mathrm{e}}(u^\prime)]=0.005$')

plt.annotate('(c) lr=2.e-6', (0.1, 0.9), xycoords='axes fraction', fontsize=12)
# Out:
# Text(0.1, 0.9, '(c) lr=2.e-6')
