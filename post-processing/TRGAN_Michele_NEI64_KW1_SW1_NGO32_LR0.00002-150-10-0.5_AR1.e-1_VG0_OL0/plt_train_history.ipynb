# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
filename = 'G:\\ltyworkstuff\\postdoc\\Results\\TRGAN_Michele_NEI_LR\\output\\TRGAN_Michele_NEI64_KW1_SW1_NGO32_LR0.00002-150-10-0.5_AR1.e-1_VG0_OL0\\train_history.csv'
df_train_history = pd.read_csv(filename)

# %%
boundaries = 150 + np.arange(10) * 150

# %% [markdown]
# ### *Plot the reconstruction loss $\mathcal{L}_{rec}$.*

# %%
plt.figure(figsize=(6, 4), dpi=100)
plt.xlabel('epoch', fontsize=11)
plt.ylabel('$\mathcal{L}_{rec}$', fontsize=14)

plt.plot(df_train_history.index+1, df_train_history['mse_loss'], label='training data')
plt.plot(df_train_history.index+1, df_train_history['val_mse_loss'], label='validation data')

plt.grid(axis='y')
plt.legend(loc='upper right', fontsize='large')

ymin, ymax = plt.gca().get_ylim()

for boundary in boundaries:
    plt.plot([boundary+1, boundary+1], [ymin, ymax], '--k', lw=1)

plt.ylim(ymin, ymax)
# Out:
# (0.03148239813745021, 0.07654661722481251)

# %% [markdown]
# ### *Plot the adversarial loss $\mathcal{L}_{adv}$.*

# %%
plt.figure(figsize=(6, 4), dpi=100)
plt.xlabel('epoch', fontsize=11)
plt.ylabel('$\mathcal{L}_{adv}$', fontsize=14)

plt.plot(df_train_history.index+1, df_train_history['adversarial_loss'], label='training data')
plt.plot(df_train_history.index+1, df_train_history['val_adversarial_loss'], label='validation data')

# The line $\mathcal{L}_{adv}=-\mathrm{ln}(0.5)$
plt.plot([1,1500], [-np.log(0.5),-np.log(0.5)], '--k', label='$\mathcal{L}_{adv}=-\mathrm{ln}(0.5)$')

plt.grid(axis='y')
plt.legend(loc='lower right', fontsize='large')

ymin, ymax = plt.gca().get_ylim()

for boundary in boundaries:
    plt.plot([boundary+1, boundary+1], [ymin, ymax], '--k', lw=1)

plt.ylim(ymin, ymax)

plt.annotate('(a)', (0.15, 0.9), xycoords='axes fraction', fontsize=12)
# Out:
# Text(0.15, 0.9, '(a)')

# %%
plt.figure(figsize=(6, 4), dpi=100)
plt.xlabel('epoch', fontsize=11)
plt.ylabel('$\mathcal{L}_{adv}$', fontsize=14)

plt.plot(df_train_history.index[750:]+1, df_train_history['adversarial_loss'][750:], label='training data')
plt.plot(df_train_history.index[750:]+1, df_train_history['val_adversarial_loss'][750:], label='validation data')

# The line $\mathcal{L}_{adv}=-\mathrm{ln}(0.5)$
plt.plot([751,1500], [-np.log(0.5),-np.log(0.5)], '--k', label='$\mathcal{L}_{adv}=-\mathrm{ln}(0.5)$')

plt.grid(axis='y')

ymin, ymax = plt.gca().get_ylim()

for boundary in boundaries[4:]:
    plt.plot([boundary+1, boundary+1], [ymin, ymax], '--k', lw=1)

plt.ylim(ymin, ymax)

plt.annotate('(b)', (0.15, 0.9), xycoords='axes fraction', fontsize=12)
# Out:
# Text(0.15, 0.9, '(b)')
